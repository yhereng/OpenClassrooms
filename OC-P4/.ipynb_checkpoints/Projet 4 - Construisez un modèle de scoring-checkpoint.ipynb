# %% [markdown]
# <font size = 10>\
#     Projet 4 - Build a scoring model

# %% [markdown]
# Import usefull package

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.impute import SimpleImputer

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.model_selection import RepeatedStratifiedKFold

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDClassifier

from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, precision_score, recall_score

from sklearn.datasets import make_classification

from sklearn.dummy import DummyClassifier

from sklearn.utils import resample

from sklearn.ensemble import RandomForestClassifier

from lightgbm import LGBMClassifier

from sklearn.decomposition import PCA

from sklearn.kernel_ridge import KernelRidge

from sklearn.pipeline import make_pipeline

# %% [markdown]
# # Load dataset

# %% [markdown]
# ## Working with the Loan appplication data set

# %% [markdown]
# ### Training data

# %%
app_train = pd.read_csv('data/application_train.csv')
print('Training data shape: ', app_train.shape)
# Out:
# Training data shape:  (307511, 122)

# %% [markdown]
# ### Kaggle Testing dataset

# %%
app_test = pd.read_csv('data/application_test.csv')
print('Testing data shape: ', app_test.shape)
# Out:
# Testing data shape:  (48744, 121)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Distribution of the target

# %%
app_train['TARGET'].value_counts()
# Out:
# 0    282686
# 1     24825
# Name: TARGET, dtype: int64

# %% [markdown]
# ## Missing values

# %%
(app_train.isna().sum(axis = 0) / app_train.shape[0]).sort_values(ascending=False)[0:20]
# Out:
# COMMONAREA_MEDI             0.698723
# COMMONAREA_AVG              0.698723
# COMMONAREA_MODE             0.698723
# NONLIVINGAPARTMENTS_MODE    0.694330
# NONLIVINGAPARTMENTS_MEDI    0.694330
# NONLIVINGAPARTMENTS_AVG     0.694330
# FONDKAPREMONT_MODE          0.683862
# LIVINGAPARTMENTS_MEDI       0.683550
# LIVINGAPARTMENTS_MODE       0.683550
# LIVINGAPARTMENTS_AVG        0.683550
# FLOORSMIN_MEDI              0.678486
# FLOORSMIN_MODE              0.678486
# FLOORSMIN_AVG               0.678486
# YEARS_BUILD_MEDI            0.664978
# YEARS_BUILD_AVG             0.664978
# YEARS_BUILD_MODE            0.664978
# OWN_CAR_AGE                 0.659908
# LANDAREA_MODE               0.593767
# LANDAREA_AVG                0.593767
# LANDAREA_MEDI               0.593767
# dtype: float64

# %% [markdown]
# ## Feature types

# %%
app_train.dtypes.value_counts()
# Out:
# float64    65
# int64      41
# object     16
# dtype: int64

# %% [markdown]
# ### Encoding Categorical Variables

# %% [markdown]
# Encode with labelEncoder for 2 unique categories or use get_dumies

# %%
from sklearn.preprocessing import LabelEncoder


# Create a label encoder object
le = LabelEncoder()
le_count = 0

# Iterate through the columns
for col in app_train:
    if app_train[col].dtype == 'object':
        # If 2 or fewer unique categories
        if len(list(app_train[col].unique())) <= 2:
            # Train on the training data
            le.fit(app_train[col])
            # Transform both training and testing data
            app_train[col] = le.transform(app_train[col])
            app_test[col] = le.transform(app_test[col])
            
            # Keep track of how many columns were label encoded
            le_count += 1
            
print('%d columns were label encoded.' % le_count)
# Out:
# 3 columns were label encoded.

# %%
# one-hot encoding of categorical variables
app_train = pd.get_dummies(app_train)
app_test = pd.get_dummies(app_test)

print('Training Features shape: ', app_train.shape)
print('Testing Features shape: ', app_test.shape)
# Out:
# Training Features shape:  (307511, 243)
# Testing Features shape:  (48744, 239)

# %%
train_labels = app_train['TARGET']

# Align the training and testing data, keep only columns present in both dataframes
app_train, app_test = app_train.align(app_test, join = 'inner', axis = 1)

# Add the target back in
app_train['TARGET'] = train_labels

print('Training Features shape: ', app_train.shape)
print('Testing Features shape: ', app_test.shape)
# Out:
# Training Features shape:  (307511, 240)
# Testing Features shape:  (48744, 239)

# %%
app_train.to_pickle('data/app_train_encode_categ')
app_test.to_pickle('data/app_test_encode_categ')

# %% [markdown]
# ### Outliers in numerical features

# %%
app_train=pd.read_pickle('data/app_train_encode_categ')
app_test=pd.read_pickle('data/app_test_encode_categ')

# %% [markdown]
# Print the describe function on the numerical columns to check for outliers

# %%
app_num=app_train.select_dtypes(include=['float64','int64'])

# %%
def show_describe(i):
    return app_num.describe().iloc[:,(i-1)*10:i*10]

# %%
widgets.interact(show_describe, i=10)
# Out:
# interactive(children=(IntSlider(value=10, description='i', max=30, min=-10), Output()), _dom_classes=('widget-…
# <function __main__.show_describe(i)>

# %%
suspected_outliers=['DAYS_EMPLOYED',
                    'OBS_30_CNT_SOCIAL_CIRCLE',
                    'DEF_30_CNT_SOCIAL_CIRCLE',
                    'OBS_60_CNT_SOCIAL_CIRCLE',
                    'DEF_60_CNT_SOCIAL_CIRCLE',
                    'AMT_REQ_CREDIT_BUREAU_HOUR',
                    'AMT_REQ_CREDIT_BUREAU_DAY',
                    'AMT_REQ_CREDIT_BUREAU_WEEK',
                    'AMT_REQ_CREDIT_BUREAU_MON',
                    'AMT_REQ_CREDIT_BUREAU_QRT',
                    'AMT_REQ_CREDIT_BUREAU_YEAR',
                    'HOUR_APPR_PROCESS_START'
                   ]

# %%
i=0
colors=sns.color_palette("Set3", 14)
plt.figure(figsize=(10,10))
for col in suspected_outliers:
    i+=1
    plt.subplot(5,3,i)
    sns.boxplot(x=app_train[col],color=colors[i%12])
plt.tight_layout()

# %% [markdown]
# #### DAYS_EMPLOYED

# %%
app_train[app_train['DAYS_EMPLOYED']>200000].shape
# Out:
# (55374, 240)

# %%
sns.boxplot(x=app_train['DAYS_EMPLOYED'])
# Out:
# <AxesSubplot:xlabel='DAYS_EMPLOYED'>

# %%
# Create an anomalous flag column
app_train['DAYS_EMPLOYED_ANOM'] = app_train["DAYS_EMPLOYED"] == 365243

# Replace the anomalous values with nan
app_train['DAYS_EMPLOYED'].replace({365243: np.nan}, inplace = True)

# Apply the same steps to the test data
app_test['DAYS_EMPLOYED_ANOM'] = app_test["DAYS_EMPLOYED"] == 365243
app_test["DAYS_EMPLOYED"].replace({365243: np.nan}, inplace = True)

# %% [markdown]
# #### Social circle features

# %%
app_train[app_train['OBS_30_CNT_SOCIAL_CIRCLE']>100].shape
# Out:
# (1, 241)

# %%
app_train.drop(index=app_train[app_train['OBS_30_CNT_SOCIAL_CIRCLE']>100].index,inplace=True)

# %%
sns.boxplot(x=app_train['DEF_30_CNT_SOCIAL_CIRCLE'])
# Out:
# <AxesSubplot:xlabel='DEF_30_CNT_SOCIAL_CIRCLE'>

# %%
app_train[(app_train['DEF_30_CNT_SOCIAL_CIRCLE']>1.5) & (app_train['DEF_30_CNT_SOCIAL_CIRCLE']<2.5)].shape
# Out:
# (5323, 241)

# %%
app_train[(app_train['OBS_30_CNT_SOCIAL_CIRCLE']>15) & (app_train['OBS_30_CNT_SOCIAL_CIRCLE']<25)].shape
# Out:
# (418, 241)

# %%
sns.scatterplot(x=app_train['DEF_60_CNT_SOCIAL_CIRCLE'],y=app_train['OBS_60_CNT_SOCIAL_CIRCLE'])
# Out:
# <AxesSubplot:xlabel='DEF_60_CNT_SOCIAL_CIRCLE', ylabel='OBS_60_CNT_SOCIAL_CIRCLE'>

# %%
i=0
colors=sns.color_palette("Set3", 14)
plt.figure(figsize=(10,10))
for col in suspected_outliers:
    i+=1
    plt.subplot(5,3,i)
    sns.boxplot(x=app_train[col],color=colors[i%12])
plt.tight_layout()

# %% [markdown]
# #### Amount of request features

# %%
sns.boxplot(x=app_train['AMT_REQ_CREDIT_BUREAU_QRT'])
# Out:
# <AxesSubplot:xlabel='AMT_REQ_CREDIT_BUREAU_QRT'>

# %%
app_train[app_train['AMT_REQ_CREDIT_BUREAU_QRT']>15].shape
# Out:
# (2, 241)

# %%
app_train.drop(index=app_train[app_train['AMT_REQ_CREDIT_BUREAU_QRT']>15].index,inplace=True)

# %%
sns.boxplot(x=app_train['AMT_REQ_CREDIT_BUREAU_QRT'])
# Out:
# <AxesSubplot:xlabel='AMT_REQ_CREDIT_BUREAU_QRT'>

# %%
i=0
colors=sns.color_palette("Set3", 14)
plt.figure(figsize=(10,10))
for col in suspected_outliers:
    i+=1
    plt.subplot(5,3,i)
    sns.boxplot(x=app_train[col],color=colors[i%12])
plt.tight_layout()

# %%
app_train.to_pickle('data/app_train_outliers')
app_test.to_pickle('data/app_test_outliers')

# %% [markdown]
# ## Correlations

# %%
app_train=pd.read_pickle('data/app_train_outliers')
app_test=pd.read_pickle('data/app_test_outliers')
print('app_train shape :', app_train.shape)
print('app_test shape :',app_test.shape)
# Out:
# app_train shape : (307508, 241)
# app_test shape : (48744, 240)

# %%
correlation_matrix=app_train.corr()

# %%
#correlation_matrix.to_pickle('data/correlation_matrix')

# %%
#correlation_matrix=pd.read_pickle('data/correlation_matrix')

# %%
np.fill_diagonal(correlation_matrix.values,0)

# %%
correlation_abs_matrix = correlation_matrix.abs()

# %%
corr_max_abs = pd.DataFrame(correlation_abs_matrix.idxmax(axis=0),columns=['feature'])

# %%
corr_max_abs['corr_coef']=correlation_abs_matrix.max(axis=0)

# %%
corr_max_abs.sort_values('corr_coef',ascending=False,inplace=True)

# %%
correlation_abs_matrix['TARGET'].sort_values(ascending=False).head(20)
# Out:
# EXT_SOURCE_3                                         0.178920
# EXT_SOURCE_2                                         0.160448
# EXT_SOURCE_1                                         0.155319
# DAYS_BIRTH                                           0.078251
# DAYS_EMPLOYED                                        0.074954
# REGION_RATING_CLIENT_W_CITY                          0.060897
# REGION_RATING_CLIENT                                 0.058903
# NAME_INCOME_TYPE_Working                             0.057472
# NAME_EDUCATION_TYPE_Higher education                 0.056585
# DAYS_LAST_PHONE_CHANGE                               0.055208
# CODE_GENDER_M                                        0.054723
# CODE_GENDER_F                                        0.054714
# DAYS_ID_PUBLISH                                      0.051451
# REG_CITY_NOT_WORK_CITY                               0.051003
# NAME_EDUCATION_TYPE_Secondary / secondary special    0.049815
# ...

# %% [markdown]
# # Baseline

# %%
def show_score(y_test,y_pred_d_cls_prob,y_pred_d_cls):
    a=roc_auc_score(y_test,y_pred_d_cls_prob)
    b=f1_score(y_test,y_pred_d_cls)
    c=accuracy_score(y_test,y_pred_d_cls)
    d=precision_score(y_test,y_pred_d_cls)
    e=recall_score(y_test,y_pred_d_cls)
    print('ROC AUC   :',a)
    print('F1        :',b)
    print('Accuracy  :',c)
    print('Precision :',d)
    print('Recall    :',e)

# %% [markdown]
# ## Test and Train split

# %%
X = app_train.drop( columns = ['TARGET'])
y = app_train['TARGET']
features = app_test.columns

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %% [markdown]
# ## Imputation of data

# %% [markdown]
# ### Using SimpleImputer

# %%
simple_imputer = SimpleImputer(strategy = 'median')

# %% [markdown]
# ## Standardization

# %%
scaler = StandardScaler()

# %%
pipeline_basic = make_pipeline(simple_imputer,scaler)
pipeline_basic.fit(X_train,y_train)
X_train_std = pipeline_basic.transform(X_train)
X_test_std = pipeline_basic.transform(X_test)

# %% [markdown]
# ## Dummy classifier

# %%
cv = RepeatedStratifiedKFold(n_splits=10,n_repeats=3,random_state=1)
scoring = {'ROC AUC': 'roc_auc',
           'F1': 'f1',
           'Accuracy': 'accuracy',
           'Precision' : 'precision',
           'Recall' :'recall'}

# %%
dummy_cls = make_pipeline(simple_imputer,scaler,DummyClassifier(strategy='stratified'))

# %%
scores = cross_validate(dummy_cls,X_train,y_train, scoring = scoring, cv=cv)
for key in scores.keys():
    print (f'Mean {key} : {scores[key].mean()}' )
# Out:
# Mean fit_time : 16.815669600168864
# Mean score_time : 1.149673581123352
# Mean test_ROC AUC : 0.4997167545653646
# Mean test_F1 : 0.08069244413902889
# Mean test_Accuracy : 0.8518994615519204
# Mean test_Precision : 0.0808321722084893
# Mean test_Recall : 0.08057194885082138

# %% [markdown]
# ## Kaggle Submission

# %%
def kaggle_submit(estimator,data,output_name = 'submission_default.csv'):
    kaggle_pred = estimator.predict_proba(data)[:,1]
    kaggle_df = pd.DataFrame(data['SK_ID_CURR'],columns=['SK_ID_CURR'])
    kaggle_df['TARGET'] = kaggle_pred
    kaggle_df.to_csv('data/'+output_name,index = False)

# %%
dummy_cls.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('dummyclassifier', DummyClassifier(strategy='stratified'))])

# %%
kaggle_submit(dummy_cls,app_test,output_name='dummy_classifier.csv')

# %% [markdown]
# Kaggle gives 0.49

# %% [markdown]
# # Class Unbalance

# %%
plt.hist(y_train)
plt.xlabel('Target')
plt.ylabel('Counts')
plt.title('Target values count')
plt.show()

# %% [markdown]
# ## Class unbalanced strategy

# %% [markdown]
# ### Over sampling

# %%
X_up,y_up = resample(X_train_std[y_train == 1],
                     y_train[y_train == 1],
                     replace=True,
                     n_samples=X_train_std[y_train == 0].shape[0])

# %%
X_train_up = np.vstack((X_train_std[y_train == 0], X_up))
y_train_up = np.hstack((y_train[y_train == 0], y_up))

# %%
plt.hist(y_train_up)
plt.xlabel('Target')
plt.ylabel('Counts')
plt.title('Target values count with resampling')
plt.show()

# %% [markdown]
# ### Data augmentation Using SMOTE

# %%
oversample = imblearn.over_sampling.SMOTE(sampling_strategy = 0.4)
undersample = imblearn.under_sampling.RandomUnderSampler(sampling_strategy = 0.7)

# %%
pipeline_smote = imblearn.pipeline.Pipeline(steps = [('over',oversample),('under',undersample)])

# %%
X_train_smote,y_train_smote = pipeline_smote.fit_resample(X_train_std,y_train)

# %%
plt.hist(y_train_smote)
plt.xlabel('Target')
plt.ylabel('Counts')
plt.title('Target values count with SMOTE')
plt.show()

# %%
X_train_smote.shape
# Out:
# (233419, 240)

# %%
X_train_std.shape
# Out:
# (261381, 240)

# %% [markdown]
# ## Strategy comparison

# %% [markdown]
# ### No resampling

# %%
cv = RepeatedStratifiedKFold(n_splits=10,n_repeats=3,random_state=1)
scoring = {'ROC AUC': 'roc_auc',
           'F1': 'f1',
           'Accuracy': 'accuracy',
           'Precision' : 'precision',
           'Recall' :'recall'}

# %%
lg = LogisticRegression(C=0.01,max_iter=200)

# %%
scores = cross_validate(lg,X_train_std,y_train, scoring = scoring, cv=cv, n_jobs=4)
for key in scores.keys():
    print (f'Mean {key} : {scores[key].mean()}' )
# Out:
# Mean fit_time : 32.18892774581909
# Mean score_time : 0.15633923212687176
# Mean test_ROC AUC : 0.7461607151135485
# Mean test_F1 : 0.022638303121359126
# Mean test_Accuracy : 0.9193157368082497
# Mean test_Precision : 0.5063148676982371
# Mean test_Recall : 0.011582647751268355

# %% [markdown]
# ### Using balanced option

# %%
lg_bal = LogisticRegression(C=0.01, class_weight='balanced',max_iter=200)

# %%
scores = cross_validate(lg_bal,X_train_std,y_train, scoring = scoring, cv=cv, n_jobs=4)
for key in scores.keys():
    print (f'Mean {key} : {scores[key].mean()}' )
# Out:
# Mean fit_time : 51.75652005672455
# Mean score_time : 0.17374982039133707
# Mean test_ROC AUC : 0.7464796057899288
# Mean test_F1 : 0.25949643027020064
# Mean test_Accuracy : 0.6880798465447265
# Mean test_Precision : 0.16050367313283687
# Mean test_Recall : 0.6771583981087596

# %% [markdown]
# ### Upsampling using smote

# %%
lg_smote = imblearn.pipeline.Pipeline(steps = [('over',oversample),('under',undersample),('model',lg)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-118b5a9113fe> in <module>
# ----> 1 lg_smote = imblearn.pipeline.Pipeline(steps = [('over',oversample),('under',undersample),('model',lg)])
#
# NameError: name 'oversample' is not defined

# %%
scores = cross_validate(lg_smote,X_train_std,y_train, scoring = scoring, cv=cv, n_jobs=4)
for key in scores.keys():
    print (f'Mean {key} : {scores[key].mean()}' )
# Out:
# Mean fit_time : 298.4301399072011
# Mean score_time : 0.31133998235066734
# Mean test_ROC AUC : 0.7384325127304846
# Mean test_F1 : 0.2793368381765592
# Mean test_Accuracy : 0.7773773472770735
# Mean test_Precision : 0.18907012487620406
# Mean test_Recall : 0.5345811938154168

# %% [markdown]
# # Feature Selection

# %%
def features_importance_lg(estimator,features,n_features_plot = 40,plot = False):
    
    estimator_coef=pd.DataFrame(estimator.coef_.reshape(features.shape[0],),columns=['coeff'])
    estimator_coef['importance']=np.abs(estimator_coef['coeff'])
    estimator_coef['abs_relative_importance']=estimator_coef['importance']/estimator_coef['importance'].sum()
    estimator_coef['sign']=np.sign(estimator_coef['coeff'])
    estimator_coef['feature']=features.values
    estimator_coef = estimator_coef.sort_values(by='abs_relative_importance',ascending=False)
    
    if plot == True:
        plt.figure(figsize=(10,10))
        sns.barplot(data=estimator_coef.head(n_features_plot),x ='abs_relative_importance',y='feature',hue='sign',dodge=False)
        
    return estimator_coef

# %%
feature_importance={}

# %% [markdown]
# ## Logistic regression

# %%
lr_bal = LogisticRegression(C = 0.01, max_iter = 200, class_weight = 'balanced')

# %%
pipeline_lr = make_pipeline(simple_imputer,scaler,lr_bal)

# %%
pipeline_lr.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=0.01, class_weight='balanced',
#                                     max_iter=200))])

# %%
feature_importance['lg_bal'] = features_importance_lg(lr_bal,features,plot=True)

# %% [markdown]
# kaggle submission

# %%
kaggle_submit(pipeline_lr,app_test,output_name='logistic_regression_balanced_option.csv')

# %% [markdown]
# Kaggle gives 0.73956

# %% [markdown]
# ## Random forest

# %%
def features_importance_rdf(estimator,features,n_features_plot = 40, plot = False):
    
    estimator_coef=pd.DataFrame(estimator.feature_importances_.reshape(features.shape[0],),columns=['coeff'])
    estimator_coef['importance']=np.abs(estimator_coef['coeff'])
    estimator_coef['abs_relative_importance']=estimator_coef['importance']/estimator_coef['importance'].sum()
    estimator_coef['sign']=np.sign(estimator_coef['coeff'])
    estimator_coef['feature']=features.values
    estimator_coef = estimator_coef.sort_values(by='abs_relative_importance',ascending=False)
    
    if plot == True:
        plt.figure(figsize=(10,10))
        sns.barplot(data=estimator_coef.head(n_features_plot),x ='abs_relative_importance',y='feature',hue='sign',dodge=False)
        
    return estimator_coef

# %%
rdf = RandomForestClassifier(n_estimators= 100, class_weight="balanced")

# %%
pipeline_rdf = make_pipeline(simple_imputer,scaler,rdf)

# %%
pipeline_rdf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(class_weight='balanced'))])

# %%
feature_importance['rdf'] = features_importance_rdf(rdf,features,plot = True)

# %%
kaggle_submit(pipeline_rdf,app_test,output_name='random_forest_balanced_option.csv')

# %% [markdown]
# gives 0.70936

# %% [markdown]
# ## SGD Classifier

# %%
sgd = SGDClassifier(class_weight='balanced',loss='modified_huber')

# %%
pipeline_sgd = make_pipeline(simple_imputer,scaler,sgd)

# %%
pipeline_sgd.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('sgdclassifier',
#                  SGDClassifier(class_weight='balanced',
#                                loss='modified_huber'))])

# %%
feature_importance['SGDClassifier'] = features_importance_lg(sgd,features,plot = True)

# %%
kaggle_submit(pipeline_sgd,app_test,output_name='sgd_balanced_option.csv')

# %% [markdown]
# gives 0.696

# %% [markdown]
# ## LGB

# %%
lgb = LGBMClassifier(class_weight='balanced')

# %%
pipeline_lgb = make_pipeline(simple_imputer,scaler,lgb)

# %%
pipeline_lgb.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('lgbmclassifier', LGBMClassifier(class_weight='balanced'))])

# %%
feature_importance['lgb'] = features_importance_rdf(lgb,features,plot = True)

# %%
kaggle_submit(pipeline_lgb,app_test,output_name='lgb_balanced_option.csv')

# %% [markdown]
# kaggle gives 0.7403

# %% [markdown]
# ## Feature importance results

# %%
feature_importance.keys()
# Out:
# dict_keys(['lg_bal', 'rdf', 'SGDClassifier', 'lgb'])

# %%
feature_importance_results = pd.DataFrame(index = features)

# %%
feature_importance_results['counts']=0
feature_importance_results['total importance']=0

# %%
for key in feature_importance.keys():
    for feature in feature_importance[key]['feature']:
        feature_importance_results.loc[feature,'counts']+=1
        feature_importance_results.loc[feature,'total importance']+= feature_importance[key].where(feature_importance[key]['feature'] == feature )['abs_relative_importance'].sum()

# %% [markdown]
# ## Reducing number of feature

# %%
selected_features = feature_importance_results[feature_importance_results['total importance']>0.01].index
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]
app_test_selected = app_test[selected_features]

# %%
selected_features.shape
# Out:
# (100,)

# %% [markdown]
# ### Effect on Logistic regression

# %%
pipeline_lr.fit(X_train_selected,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=0.01, class_weight='balanced',
#                                     max_iter=200))])

# %%
kaggle_submit(pipeline_lr,app_test_selected,output_name='lr_balanced_option_selected.csv')

# %% [markdown]
# Kaggle gives 0.73627 was 0.73956

# %% [markdown]
# ### Effect on SGD

# %%
pipeline_sgd.fit(X_train_selected,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('sgdclassifier',
#                  SGDClassifier(class_weight='balanced',
#                                loss='modified_huber'))])

# %%
kaggle_submit(pipeline_sgd,app_test_selected,output_name='sgd_balanced_option_selected.csv')

# %% [markdown]
# Kaggle gives 0.64 was 0.696

# %% [markdown]
# ### Effect on Random Forest

# %%
pipeline_rdf.fit(X_train_selected,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(class_weight='balanced'))])

# %%
kaggle_submit(pipeline_rdf,app_test_selected,output_name='rdf_balanced_option_selected.csv')

# %% [markdown]
# Kaggle gives 0.70812 was 0.70936

# %% [markdown]
# ### Effect on LGB

# %%
pipeline_lgb.fit(X_train_selected,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('lgbmclassifier', LGBMClassifier(class_weight='balanced'))])

# %%
kaggle_submit(pipeline_lr,app_test_selected,output_name='lgb_balanced_option_selected.csv')

# %% [markdown]
# Kaggle gives 0.73627 was 0.7403

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Synthetic features using PCA

# %%
pca = PCA(n_components=2)
pca.fit(X_train_std)
pca.explained_variance_ratio_
# Out:
# array([0.0782586 , 0.02861976])

# %%
PC1 = pd.DataFrame(pca.components_[0],columns=['coef'])
PC1['feature'] = features
PC2 = pd.DataFrame(pca.components_[1],columns=['coef'])
PC2['feature'] = features

# %%
PC1 = PC1.sort_values(by='coef',ascending=False)
PC2 = PC2.sort_values(by='coef',ascending=False)

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=PC1.head(30),x ='coef',y='feature')
# Out:
# <AxesSubplot:xlabel='coef', ylabel='feature'>

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=PC2.head(30),x ='coef',y='feature')
# Out:
# <AxesSubplot:xlabel='coef', ylabel='feature'>

# %%
X_train_pca = pca.transform(X_train_std)
X_test_pca = pca.transform(X_test_std)

# %%
X_train_pca = np.hstack((X_train_std,X_train_pca))
X_test_pca = np.hstack((X_test_std,X_test_pca))

# %%
features_pca = features.append(pd.Index(['PC1','PC2']))

# %%
X_train_pca.shape
# Out:
# (261381, 242)

# %%
lg = LogisticRegression(C=0.001,class_weight='balanced')
lg.fit(X_train_pca,y_train)

# %%
A =features_importance_lg(lg,features_pca,n_features=40,plot = True)

# %%
rdf.fit(X_train_pca,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200, n_jobs=4)

# %%
A = features_importance_rdf(rdf,features_pca,n_features=40,plot = True)

# %% [markdown]
# ## Business Features

# %% [markdown]
# ### Creating the features

# %%
app_train_busi = app_train.copy()
app_test_busi = app_test.copy()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-289-a3a61e13bf2f> in <module>
# ----> 1 app_train_busi = app_train.copy()
#       2 app_test_busi = app_test.copy()
#
# ~\Code\Install\anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5661         dtype: object
#    5662         """
# -> 5663         data = self._mgr.copy(deep=deep)
#    5664         self._clear_item_cache()
#    5665         return self._constructor(data).__finalize__(self, method="copy")
#
# ~\Code\Install\anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     800             new_axes = list(self.axes)
#     801
# --> 802         res = self.apply("copy", deep=deep)
#     803         res.axes = new_axes
#     804         return res
#
# ...

# %%
X = app_train.drop( columns = ['TARGET'])
y = app_train['TARGET']
features = app_test.columns

# %%
app_train_busi['ANNUITY_INCOME_RATIO'] = app_train['AMT_ANNUITY']/app_train['AMT_INCOME_TOTAL']
app_test_busi['ANNUITY_INCOME_RATIO'] = app_test['AMT_ANNUITY']/app_test['AMT_INCOME_TOTAL']

# %%
app_train_busi['CREDIT_INCOME_RATIO'] = app_train['AMT_CREDIT']/app_train['AMT_INCOME_TOTAL']
app_test_busi['CREDIT_INCOME_RATIO'] = app_test['AMT_CREDIT']/app_test['AMT_INCOME_TOTAL']

# %%
app_train_busi['DAYS_EMPLOYED_DAYS_BIRTH_RATIO'] = app_train['DAYS_EMPLOYED']/(app_train['DAYS_BIRTH']+365*16)
app_test_busi['DAYS_EMPLOYED_DAYS_BIRTH_RATIO'] = app_test['DAYS_EMPLOYED']/(app_test['DAYS_BIRTH']+365*16)

# %%
selected_features_busi = selected_features.append(pd.Index(['ANNUITY_INCOME_RATIO',
                                                   'CREDIT_INCOME_RATIO',
                                                   'DAYS_EMPLOYED_DAYS_BIRTH_RATIO']))

# %%
app_test_busi = app_test_busi[selected_features_busi]
X_busi = app_train_busi.drop( columns = ['TARGET'])[selected_features_busi]
y_busi = app_train_busi['TARGET']

# %%
app_test_busi.shape

# %%
X_train_busi, X_test_busi, y_train_busi, y_test_busi = train_test_split(X_busi, y_busi, test_size=0.15, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %%
pipeline_lr.fit(X_train_busi,y_train_busi)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=0.01, class_weight='balanced',
#                                     max_iter=200))])

# %%
A = features_importance_lg(lr_bal,selected_features_busi,n_features=40,plot=True)

# %%
kaggle_submit(pipeline_lr,app_test_busi,'lr_balanced_option_busi.csv')

# %% [markdown]
# ### Random Forest

# %%
pipeline_rdf.fit(X_train_busi,y_train_busi)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(class_weight='balanced',
#                                         n_estimators=200))])

# %%
A = features_importance_rdf(rdf,selected_features_busi,n_features=40,plot=True)

# %%
kaggle_submit(pipeline_rdf,app_test_busi,'rdf_balanced_option_busi.csv')

# %%
pipeline_rdf.predict(X_train_busi).sum()
# Out:
# 21095

# %% [markdown]
# ### SGDClassifier

# %%
pipeline_sgd.fit(X_train_busi,y_train_busi)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('sgdclassifier',
#                  SGDClassifier(class_weight='balanced',
#                                loss='modified_huber'))])

# %%
A = features_importance_lg(sgd,selected_features_busi,n_features=40,plot=True)

# %%
kaggle_submit(pipeline_sgd,app_test_busi,'sgd_balanced_option_busi.csv')

# %% [markdown]
# ### LGB

# %%
pipeline_lgb.fit(X_train_busi,y_train_busi)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler()),
#                 ('lgbmclassifier', LGBMClassifier(class_weight='balanced'))])

# %%
A = features_importance_rdf(lgb,selected_features_busi,n_features=40,plot=True)

# %%
kaggle_submit(pipeline_lgb,app_test_busi,'lgb_balanced_option_busi.csv')

# %% [markdown]
# # Tuning the selected model

# %% [markdown]
# ### Hyperparameter tuning

# %%
# Parameter grid
param_grid = {'C': [0.01,0.1,1]}

# score to optimize
score = 'roc_auc'

# Creating a classifier with GridSearch optimization on hyparameter C
clf = GridSearchCV(
    LogisticRegression(max_iter=200), # classifier
    param_grid,     # hyperparameter C
    cv=5,           # number of fold for cross validation
    scoring=score,   # score à optimiser
    n_jobs=-1,
)

# Fit on training dataset
clf.fit(X_train_scaled, y_train)

# Show best hyperparameters
print("Best parameters on training dataset:")
print(clf.best_params_)

# Show performance
print("Cross validation results :")
for mean, std, params in zip(
        clf.cv_results_['mean_test_score'], # score moyen
        clf.cv_results_['std_test_score'],  # écart-type du score
        clf.cv_results_['params']           # valeur de l'hyperparamètre
    ):

    print("{} = {:.3f} (+/-{:.03f}) for {}".format(
        score,
        mean,
        std*2,
        params
    ) )
# Out:
# Best parameters on training dataset:
# {'C': 0.03162277660168379}
# Cross validation results :
# roc_auc = 0.720 (+/-0.008) for {'C': 1e-05}
# roc_auc = 0.734 (+/-0.007) for {'C': 3.1622776601683795e-05}
# roc_auc = 0.742 (+/-0.006) for {'C': 0.0001}
# roc_auc = 0.744 (+/-0.006) for {'C': 0.00031622776601683794}
# roc_auc = 0.744 (+/-0.006) for {'C': 0.001}
# roc_auc = 0.745 (+/-0.006) for {'C': 0.0031622776601683794}
# roc_auc = 0.746 (+/-0.006) for {'C': 0.01}
# roc_auc = 0.746 (+/-0.006) for {'C': 0.03162277660168379}
# roc_auc = 0.746 (+/-0.006) for {'C': 0.1}
# roc_auc = 0.746 (+/-0.006) for {'C': 0.31622776601683794}
# roc_auc = 0.746 (+/-0.006) for {'C': 1.0}

# %%
lg = LogisticRegression(C=0.0005)

# %%
lg.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression(C=0.0005)

# %%
log_reg_pred = lg.predict_proba(X_test_scaled)[:,1]

# %%
log_reg_pred.shape
# Out:
# (46127,)

# %%
roc_auc_score(y_test,log_reg_pred)
# Out:
# 0.7461064569258018

# %% [markdown]
# #### Submitting to kaggle

# %%
def kaggle_submit(estimator,data,output_name = 'submission_default.csv'):
    kaggle_pred = estimator.predict(data)
    kaggle_df = pd.DataFrame(data['SK_ID_CURR'],columns=['SK_ID_CURR'])
    kaggle_df['TARGET'] = kaggle_pred
    kaggle_df.to_csv('data/'+output_name,index = False)
